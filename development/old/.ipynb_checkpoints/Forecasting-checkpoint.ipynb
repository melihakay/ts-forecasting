# %% [markdown]
# # Demand Forecasting from Sales Data

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
plt.rcParams["figure.figsize"] = 12,6

# %% [markdown]
# ## Import Data and Preprocess

# %%
path        = "satis.xlsx"
df          = pd.read_excel(path, index_col="DateId", parse_dates=True)

# df.DateId   = pd.to_datetime(df.DateId)
# df["Month"] = df.index.dt.to_period("M")

# %%
first_date, last_date = df.index.min(), df.index.max()
df["DaystoLastDate"]  = (last_date - df.index).days 

columns     = ["ProductId", "ProductBasePrice", "DiscountRate", "Amount", "DaystoLastDate", "Total"]
df          = df[columns]
df.head()
# Out:
#             ProductId  ProductBasePrice  DiscountRate  Amount  DaystoLastDate  \
# DateId
# 2020-04-09      12555              9.52             0     960            1360
# 2020-04-09      12556             12.68             0    1200            1360
# 2020-04-09      12557             13.62             0    1392            1360
# 2020-04-09      12558             10.22             0     816            1360
# 2020-04-09      12563             23.92             0     816            1360
#
#                Total
# DateId
# 2020-04-09   9139.20
# 2020-04-09  15216.00
# 2020-04-09  18959.04
# 2020-04-09   8339.52
# 2020-04-09  19518.72

# %%
df.describe()
# Out:
#            ProductId  ProductBasePrice   DiscountRate         Amount  \
# count  440945.000000     440945.000000  440945.000000  440945.000000
# mean    21019.605305         30.585974       3.761796      57.856984
# std     20012.552294         80.236186       8.262789     851.576862
# min     12555.000000          0.000000       0.000000  -57024.000000
# 25%     12569.000000         12.850000       0.000000       4.000000
# 50%     12639.000000         19.640000       0.000000      12.000000
# 75%     13479.000000         37.070000       4.000000      24.000000
# max     84034.000000      11017.000000     198.000000  285696.000000
#
#        DaystoLastDate         Total
# count   440945.000000  4.409450e+05
# mean       790.246087  1.576266e+03
# std        368.344725  1.998855e+04
# min          0.000000 -6.610200e+05
# 25%        526.000000  7.872000e+01
# 50%        833.000000  2.199600e+02
# 75%       1110.000000  6.598800e+02
# max       1360.000000  5.905440e+06

# %% [markdown]
# ## Analyze Data

# %%
print(f"First sale on {first_date.date()} \nLast sale on  {last_date.date()}")
print(f"Windows is {round((last_date - first_date).days / 364, 2)} years")
# Out:
# First sale on 2020-04-09
# Last sale on  2023-12-30
# Windows is 3.74 years

# %%
# Most frquently sold products

df.ProductId.value_counts().head(20).plot(kind="bar", figsize=(12, 6))
plt.title("Most frequently sold products")
plt.xlabel("Product ID")
plt.ylabel("Frequency in sales data")
# Out:
# Text(0, 0.5, 'Frequency in sales data')

# %% [markdown]
# ## Filter eligible products

# %%
# Outliers
def remove_outliers_in_sales(df, z_threshold=3):
    # Calculate z-scores for each group of ProductId
    df['z_score'] = df.groupby('ProductId')['Amount'].transform(stats.zscore)

    # Filter out rows where the absolute z-score exceeds the threshold
    filtered_df = df[abs(df['z_score']) <= z_threshold].drop(columns=['z_score'])

    return filtered_df

filtered_df = remove_outliers_in_sales(df)
filtered_df.describe()
# Out:
#            ProductId  ProductBasePrice   DiscountRate         Amount  \
# count  435694.000000     435694.000000  435694.000000  435694.000000
# mean    20991.432370         30.600528       3.689000      38.008504
# std     19981.032216         80.429498       8.200962     203.203704
# min     12555.000000          0.000000       0.000000  -10368.000000
# 25%     12569.000000         12.850000       0.000000       4.000000
# 50%     12639.000000         19.640000       0.000000      12.000000
# 75%     13479.000000         37.070000       4.000000      24.000000
# max     84034.000000      11017.000000     198.000000   10800.000000
#
#        DaystoLastDate         Total
# count   435694.000000  4.356940e+05
# mean       790.601934  1.065407e+03
# std        368.234210  7.068229e+03
# min          0.000000 -6.610200e+05
# 25%        526.000000  7.608000e+01
# 50%        834.000000  2.144000e+02
# 75%       1110.000000  6.314400e+02
# max       1360.000000  1.258598e+06

# %%
inactive_threshold = 364
long_enough        = 364
min_sales          = 100
date_quantile      = .95

filtered_df["Date"] = pd.to_datetime(filtered_df.index)

product_details                                 = filtered_df.groupby("ProductId")["Date"].agg(["min", "max"])
product_details.columns                         = ["first_sale", "last_sale"]

# Date Related
product_details["days_between"]                 = (product_details["last_sale"] - product_details["first_sale"]).dt.days
product_details["days_since_last_sale"]         = (last_date - product_details.last_sale).dt.days

# Validity of the product
product_details["inactive"]                     = product_details["days_since_last_sale"].apply(lambda day: day > inactive_threshold)
product_details["sold_long_enough"]             = product_details["days_between"].apply(lambda days: days > long_enough)

# Sales volume
product_details["total_sale_amount"]            = filtered_df.groupby("ProductId")["Amount"].sum()
product_details["sale_amount_per_month"]        = product_details["total_sale_amount"] / (product_details["days_between"] / 30)

# Sales count
product_details["quantile_sales_date"]          = filtered_df.query("Amount > 0").groupby("ProductId")["Date"].agg(lambda x: x.quantile(date_quantile))
product_details["quantile_days_to_last_sale"]   = (last_date - product_details["quantile_sales_date"]).dt.days
product_details["quantile_test"]                = product_details["quantile_days_to_last_sale"].apply(lambda days: days <= 1.5 * inactive_threshold)

# Filter
query_               = """inactive              == False and \
                          sold_long_enough      == True and \
                          sale_amount_per_month >= @min_sales and\
                          quantile_test         == True"""
eligible_products                               = product_details.query(query_)

print(f"{eligible_products.count().min()} of {len(df.ProductId.unique())} are eligible for forecasting.")

del filtered_df["Date"]
# Out:
# 141 of 292 are eligible for forecasting.

# %%
product_details[~(product_details.index.isin(eligible_products.index))].sort_values(by="days_between").head(20)
# Out:
#           first_sale  last_sale  days_between  days_since_last_sale  inactive  \
# ProductId
# 83537     2023-08-26 2023-08-29             3                   123     False
# 83566     2023-08-26 2023-08-30             4                   122     False
# 84029     2023-12-18 2023-12-27             9                     3     False
# 84034     2023-12-13 2023-12-28            15                     2     False
# 13486     2020-05-28 2020-06-15            18                  1293      True
# 83396     2023-05-30 2023-06-23            24                   190     False
# 84028     2023-12-01 2023-12-29            28                     1     False
# 84027     2023-12-01 2023-12-29            28                     1     False
# 84026     2023-12-01 2023-12-29            28                     1     False
# 84025     2023-12-01 2023-12-29            28                     1     False
# 84030     2023-11-30 2023-12-28            28                     2     False
#
#            sold_long_enough  total_sale_amount  sale_amount_per_month  \
# ProductId
# 12555                  True            3459342           76309.014706
# 12556                  True             966671           21323.625000
# 12557                  True             635585           14020.257353
# 12560                  True              10508             232.477876
# 12561                  True              32853             724.698529
# 12562                  True              17149             378.286765
# 12563                  True             318474            7025.161765
# 12564                  True              72824            1625.535714
# 12565                  True             336601            7425.022059
# 12566                  True             147299            3261.232472
#
#           quantile_sales_date  quantile_days_to_last_sale  quantile_test
# ProductId
# 12555     2023-08-15 00:00:00                       137.0           True
# 12556     2022-07-20 00:00:00                       528.0           True
# 12557     2023-08-01 00:00:00                       151.0           True
# 12560     2023-06-06 09:36:00                       206.0           True
# 12561     2023-06-22 00:00:00                       191.0           True
# 12562     2023-06-17 00:00:00                       196.0           True
# 12563     2023-06-14 00:00:00                       199.0           True
# 12564     2023-05-24 00:00:00                       220.0           True
# 12565     2023-06-15 00:00:00                       198.0           True
# 12566     2023-06-24 00:00:00                       189.0           True

# %%
eligible_sales          = filtered_df.query("ProductId.isin(@eligible_products.index)")
assert                    eligible_sales.ProductId.unique().sort() == np.array(eligible_products.index).sort()

eligible_sales_by_month = eligible_sales.resample("ME")["Total"].sum()
eligible_sales_by_month.plot()
# Out:
# <Axes: xlabel='DateId'>

# %% [markdown]
# ### Analyze Product (TODO)

# %%
#TODO : Add weighted sum for discount rate
def analyze_product(product_id):
    product_data       = df.query(f"ProductId == {product_id}")
    
    monthly_amount_sum = product_data.resample("ME").sum()["Amount"].plot()
    plt.axhline(0, color="red")

# %%
analyze_product(13486)

# %% [markdown]
# ## Discount

# %%
product = filtered_df.query("ProductId == 12557")
product.resample("ME").mean()["DiscountRate"].plot();

# %% [markdown]
# ## Trend

# %%
from statsmodels.tsa.filters.hp_filter import hpfilter

# %%
product_df = filtered_df.resample("ME").sum()
product_df["trend"], product_df["cycle"] = hpfilter(product_df["Amount"], lamb=1600)
product_df["hp_sum"] = product_df.trend + product_df.cycle

# %%
product_df[["Amount", "trend"]].plot()
# Out:
# <Axes: xlabel='DateId'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
result = seasonal_decompose(product_df["Amount"], model="addititive")
result.plot();

# %%
product_df["Amount"].ewm(span=12).mean().plot()
# Out:
# <Axes: xlabel='DateId'>

# %%
# Holt
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
product_df.Total.plot()
# Out:
# <Axes: xlabel='DateId'>

# %%
product_df["DES_12"] = ExponentialSmoothing(product_df["Amount"], trend="add").fit().fittedvalues.shift(-1)
# Out:
# /opt/conda/lib/python3.11/site-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
product_df[["Amount", "DES_12"]].plot()
# Out:
# <Axes: xlabel='DateId'>

# %%
product_df["TES_12"] = ExponentialSmoothing(
    product_df["Amount"], 
    trend="add",
    seasonal = "add",
    seasonal_periods = 12).fit().fittedvalues
# Out:
# /opt/conda/lib/python3.11/site-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
product_df[["Amount", "DES_12", "TES_12"]].plot()
# Out:
# <Axes: xlabel='DateId'>

# %%
rmse = np.sqrt(np.power((product_df["Amount"] - product_df["TES_12"]), 2)).mean()

# %%
rmse
# Out:
# 4278.057665627316

# %%
me / product_df["Amount"].mean()
# Out:
# -0.056847249464883266
