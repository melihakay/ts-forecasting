# %% [markdown]
# # Data Preperation and SARIMAX for SC Johnson sales

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from   scipy import stats

# %%
plt.rcParams["figure.figsize"] = 12,6

# %% [markdown]
# ## Read Data

# %%
path        = "satis.xlsx"
df          = pd.read_excel(path, index_col="DateId", parse_dates=True)
df.head()
# Out:
#             DistributorId  CustomerId  Channel-Id  ProductId  \
# DateId
# 2020-04-09             10       36485         274      12555
# 2020-04-09             10       36485         274      12556
# 2020-04-09             10       36485         274      12557
# 2020-04-09             10       36485         274      12558
# 2020-04-09             10       36485         274      12563
#
#             ProductBasePrice  DiscountRate  Amount     Total  NetTotal  \
# DateId
# 2020-04-09              9.52             0     960   9139.20  10784.26
# 2020-04-09             12.68             0    1200  15216.00  17954.88
# 2020-04-09             13.62             0    1392  18959.04  22371.67
# 2020-04-09             10.22             0     816   8339.52   9840.63
# 2020-04-09             23.92             0     816  19518.72  23032.09
#
#            InvoiceTip
# DateId
# 2020-04-09    SELLING
# 2020-04-09    SELLING
# 2020-04-09    SELLING
# 2020-04-09    SELLING
# 2020-04-09    SELLING

# %% [markdown]
# ## Invesitage Data

# %%
# Check nullity
df.isna().sum()
# Out:
# DistributorId        0
# CustomerId           0
# Channel-Id           0
# ProductId            0
# ProductBasePrice     0
# DiscountRate         0
# Amount               0
# Total                0
# NetTotal             0
# InvoiceTip           0
# AmountZScore        18
# dtype: int64

# %%
# Check duplicates
duplicate_check_df         = df.copy()
duplicate_check_df["Date"] = duplicate_check_df.index
print(duplicate_check_df.duplicated().sum(), "duplicates")

del duplicate_check_df
# Out:
# 0 duplicates

# %%
df["InvoiceTip"].value_counts(normalize=True)
# Out:
# InvoiceTip
# SELLING                   0.824781
# DAMAGED_SELLING_RETURN    0.154770
# SELLING_RETURN            0.020449
# Name: proportion, dtype: float64

# %%
def plot_amount_with_selling_type(df, lower_limit=None, upper_limit=None, plot_lim=None, title="Untitled"):
    size = 10
    
    selling_data = df.query("InvoiceTip == 'SELLING'")

    if lower_limit:
        plt.axhline(lower_limit, color="black")

    if upper_limit:
        plt.axhline(upper_limit, color="black")
    
    plt.scatter(x=selling_data.index, 
                y=selling_data["Amount"].values,
                s=size, 
                label="Selling")
    
    selling_data = df.query("InvoiceTip == 'SELLING_RETURN'")
    plt.scatter(x=selling_data.index, 
                y=selling_data["Amount"].values,
                s=size, 
                label="Return")
    
    selling_data = df.query("InvoiceTip == 'DAMAGED_SELLING_RETURN'")
    plt.scatter(x=selling_data.index, 
                y=selling_data["Amount"].values,
                s=size, 
                label="Damaged Return")
    
    plt.xlabel("Date")
    plt.ylabel("Amount")
    
    if plot_lim:
        plt.ylim(-plot_lim, plot_lim)
        
    plt.title(title)
    plt.legend()
    plt.show()

# %%
plot_amount_with_selling_type(df)

# %% [markdown]
# ## Outlier Detection

# %%
mean        = df["Amount"].mean()
std         = df["Amount"].std()

z_limit     = 10
z_threshold = mean + z_limit * std
print(z_threshold)
# Out:
# 8573.800930628802

# %%
plot_amount_with_selling_type(df, lower_limit=-z_threshold, upper_limit=z_threshold, 
                              title=f"Amount of Total Sales with {z_limit} z-score interval")

# %%
# Check outliers

outlier_data = df.query("Amount > @z_threshold or Amount < -@z_threshold").copy()
inlier_data  = df.drop(outlier_data.index)
print(f"{round(len(outlier_data) / len(df), 4)} of data is considered as outlier at {z_limit} * std level.")
print(
f"""
Mean before filtering = {df["Amount"].mean()}
Mean after filtering  = {inlier_data["Amount"].mean()}
""")
# Out:
# 0.0006 of data is considered as outlier at 10 * std level.
#
# Mean before filtering = 57.85921252270784
# Mean after filtering  = 43.715118455688796

# %% [markdown]
# Frequenct of products in outlier data

# %%
outlier_data["ProductId"].value_counts().head()
# Out:
# ProductId
# 12555    126
# 12569     37
# 12556     24
# 12659     10
# 12557      8
# Name: count, dtype: int64

# %% [markdown]
# ### Endogenous Outlier Detection

# %%
# Z Score of Amount by ProductId
df['AmountZScore'] = df.groupby('ProductId')['Amount'].transform(stats.zscore)

# %% [markdown]
# There are several null z-scores due to low amount. It would be best to drop these.

# %%
df["AmountZScore"].isna().sum()
# Out:
# 0

# %%
df = df.dropna()

# %%
# Endogenous Outlier Detection
outlier_ratio_per_product = (
    df[df["AmountZScore"] > z_limit].groupby("ProductId")["AmountZScore"].count().sort_values(ascending=False) / 
    df["ProductId"].value_counts()).rename("ratio").fillna(0)
outlier_info_df = pd.merge(left=outlier_ratio_per_product, 
                           right=df["ProductId"].value_counts(), 
                           right_index=True,
                           left_index= True,
                           how="outer")
outlier_info_df.sort_values(by="count", ascending=False).head()
# Out:
#               ratio  count
# ProductId
# 12555      0.000767  20855
# 12556      0.001514  13873
# 12557      0.002066  13066
# 12569      0.001506  11954
# 12563      0.000938  10660

# %%
plot_amount_with_selling_type(
    df[(df["AmountZScore"].abs() > z_limit)], 
    plot_lim=50_000,
    title="Endog Outliers"
)

# %%
endog_inliers = df[df["AmountZScore"].abs() < z_limit].copy()
plot_amount_with_selling_type(
    endog_inliers,
    title="Endog Inliers")

# %% [markdown]
# ### Get filtered df

# %%
filtered_df = endog_inliers[endog_inliers["InvoiceTip"].isin(["SELLING", "SELLING_RETURN"])].copy()
filtered_df.head()
# Out:
#             DistributorId  CustomerId  Channel-Id  ProductId  \
# DateId
# 2020-04-09             10       36485         274      12555
# 2020-04-09             10       36485         274      12556
# 2020-04-09             10       36485         274      12557
# 2020-04-09             10       36485         274      12558
# 2020-04-09             10       36485         274      12563
#
#             ProductBasePrice  DiscountRate  Amount     Total  NetTotal  \
# DateId
# 2020-04-09              9.52             0     960   9139.20  10784.26
# 2020-04-09             12.68             0    1200  15216.00  17954.88
# 2020-04-09             13.62             0    1392  18959.04  22371.67
# 2020-04-09             10.22             0     816   8339.52   9840.63
# 2020-04-09             23.92             0     816  19518.72  23032.09
#
#            InvoiceTip  AmountZScore
# DateId
# 2020-04-09    SELLING      0.188442
# 2020-04-09    SELLING      1.399510
# 2020-04-09    SELLING      2.848003
# 2020-04-09    SELLING      3.419612
# 2020-04-09    SELLING      2.257410

# %%
plot_amount_with_selling_type(filtered_df,
                              title="Endogenous Filtered Sales")

# %% [markdown]
# ## Feature Engineering and Product Filtering

# %%
first_date_in_df, last_date_in_df = filtered_df.index.min(), filtered_df.index.max()
filtered_df["DaystoLastDateInDf"]  = (last_date_in_df - filtered_df.index).days

# %%
print(f"First sale on {first_date.date()} \nLast sale on  {last_date.date()}")
print(f"Windows is {round((last_date - first_date).days / 364, 2)} years")
# Out:
# First sale on 2020-04-09
# Last sale on  2023-12-30
# Windows is 3.74 years

# %% [markdown]
# ### Product Details and Eligible Products

# %%
outlier_info_df.columns = ["Outlier Ratio", "Outlier Count"]
outlier_info_df.head()
# Out:
#            Outlier Ratio  Outlier Count
# ProductId
# 12555           0.000767          20855
# 12556           0.001514          13873
# 12557           0.002066          13066
# 12558           0.001400           2143
# 12559           0.001361           1469

# %%
inactive_threshold = 364
long_enough        = 364
min_sales          = 100
date_quantile      = .95

filtered_df["Date"] = pd.to_datetime(filtered_df.index)

product_details                                 = filtered_df.groupby("ProductId")["Date"].agg(["min", "max"])
product_details.columns                         = ["FirstSaleDate", "LastSaleDate"]

# Date Related
product_details["DaysSoldFor"]                  = (product_details["LastSaleDate"] - product_details["FirstSaleDate"]).dt.days
product_details["DaysSinceLastSaleDate"]        = (last_date_in_df - product_details["LastSaleDate"]).dt.days

# Validity of the product
product_details["IsActive"]                     = product_details["DaysSinceLastSaleDate"].apply(lambda day: day < inactive_threshold)
product_details["IsSoldEnough"]                 = product_details["DaysSoldFor"].apply(lambda days: days > long_enough)

# Sales volume
product_details["TotalSaleAmount"]              = filtered_df.groupby("ProductId")["Amount"].sum()
product_details["MeanSaleAmountPerMonth"]       = product_details["TotalSaleAmount"] / (product_details["DaysSoldFor"] / 30)

# Maybe we can add quantile test?

query_              = """IsActive               == True and \
                         IsSoldEnough           == True and \
                         MeanSaleAmountPerMonth >= @min_sales
                      """
eligible_products                               = product_details.query(query_).copy()

print(f"{eligible_products.count().min()} of {len(df.ProductId.unique())} products are eligible for forecasting.")

del filtered_df["Date"]
# Out:
# 180 of 282 products are eligible for forecasting.

# %%
filtered_df.columns
# Out:
# Index(['DistributorId', 'CustomerId', 'Channel-Id', 'ProductId',
#        'ProductBasePrice', 'DiscountRate', 'Amount', 'Total', 'NetTotal',
#        'InvoiceTip', 'AmountZScore', 'DaystoLastDateInDf'],
#       dtype='object')

# %%
numerical_df = filtered_df[['ProductId', 'DiscountRate', 'Amount']].copy()
numerical_df
# Out:
#             ProductId  DiscountRate  Amount
# DateId
# 2020-04-09      12555             0     960
# 2020-04-09      12556             0    1200
# 2020-04-09      12557             0    1392
# 2020-04-09      12558             0     816
# 2020-04-09      12563             0     816
# ...               ...           ...     ...
# 2023-04-13      81412             0       5
# 2023-04-13      81470             0     276
# 2023-04-13      81619             0       6
# 2023-04-13      81702             0       7
# 2023-04-13      81869             0      48
#
# [371896 rows x 3 columns]

# %% [markdown]
# ## Forecasting

# %%
def split_dataset(data, horizon, timeshift=0):
    train = data.iloc[:-(horizon + timeshift)]
    test  = data.iloc[-(horizon + timeshift):]
    return train,test

# %%
def aggregate_df(df, product_ids = None):
    if product_ids:
        df = df[df["ProductId"].isin(product_ids)].copy()
    else:
        df = df.copy()

    positive_rate = len(df[df['Amount'] > 0]) / len(df)
        
    resample = df.resample("MS")
    agg = resample[["Amount"]].sum().copy()
    
    df.loc[df["Amount"] < 0, "DiscountRate"] = 0
    positive_sale_sum = df.query("Amount > 0").resample("MS")["Amount"].sum().rename("Monthly Sum")
    df = pd.merge(left=df, left_index=True, right=positive_sale_sum, right_index=True)

    df["WeightedDiscount"] = (df["DiscountRate"] * df["Amount"]) / df["Monthly Sum"] # Percent
    agg["MeanDiscount"]    = df["WeightedDiscount"].resample("MS").sum()

    return agg

# %%
forecast_data = aggregate_df(numerical_df)

# %% [markdown]
# ### Analyze Trend

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
seasonal_decompose(forecast_data["Amount"]).plot();

# %% [markdown]
# It is clearly seen that there is yearly seasonality maximized between May and Aug. Let's check trend also using EWM

# %%
forecast_data["Amount"].ewm(span=12).mean().plot()
# Out:
# <Axes: xlabel='DateId'>

# %%
from pandas.plotting import lag_plot

# %%
lag_plot(forecast_data["Amount"], lag=12)
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 12)'>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(forecast_data["Amount"]);

# %% [markdown]
# ### Holt-Winters

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, root_mean_squared_error

# %%
model_DSA12 = ExponentialSmoothing(forecast_data["Amount"],
                                   trend="mul").fit()
forecast_data["DSA12"] = model_DSA12.fittedvalues.shift(-1)

model_TSM12 = ExponentialSmoothing(forecast_data["Amount"],
                                   trend="mul",
                                   seasonal="add",
                                   seasonal_periods=12).fit()
forecast_data["TSM12"] = model_TSM12.fittedvalues


forecast_data[["Amount", "TSA12", "DSM12"]].plot()
# Out:
# /opt/conda/lib/python3.11/site-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# <Axes: xlabel='DateId'>

# %%
# Basic Forecast

forecast_data[["Amount"]].plot()
model_DSA12.forecast(11).plot(label="DSA12 Forecast")
model_TSM12.forecast(11).plot(label="TSM12 Forecast")
plt.legend()
plt.title("Holt-Winters Forecasts")
# Out:
# Text(0.5, 1.0, 'Holt-Winters Forecasts')

# %%
def test_exponential_model(data, horizon=12, timeshift=0, trend="add", seasonal=None, periods=12, plot=True, label="Prediction"):
    """ Gets fitted model!
    """
    train, test = split_dataset(data, horizon, timeshift)
    print(f"Train last date {train.index.max()}, test first date {test.index.min()}, test last date {test.index.max()}")
    
    if seasonal:
        model = ExponentialSmoothing(train, trend=trend, seasonal=seasonal, seasonal_periods=periods).fit()
    else:
        model = ExponentialSmoothing(train, trend=trend)

    predictions = model.forecast(horizon + timeshift)
    if plot:
        test.plot()
        predictions.plot(label=label)
        plt.legend()

    error = np.abs((test.iloc[-1] - predictions.iloc[-1]))
    error_ratio = error / test.iloc[-1]
    #cum_error = mean_absolute_error(test, predictions) / test.mean()

    return  error, error_ratio

# %%
test_exponential_model(forecast_data["Amount"], horizon=2, timeshift=0, trend="mul", seasonal="add")
# Out:
# Train last date 2023-10-01 00:00:00, test first date 2023-11-01 00:00:00, test last date 2023-12-01 00:00:00
# /opt/conda/lib/python3.11/site-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# (9491.538239717804, 0.051875116766872)

# %% [markdown]
# ### ARIMA & SARIMA(X)

# %%
# !pip install statsforecast
# Out:
# Collecting statsforecast
#   Downloading statsforecast-1.7.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.11/site-packages (from statsforecast) (3.0.0)
# Requirement already satisfied: numba>=0.55.0 in /opt/conda/lib/python3.11/site-packages (from statsforecast) (0.58.1)
# Requirement already satisfied: numpy>=1.21.6 in /opt/conda/lib/python3.11/site-packages (from statsforecast) (1.26.3)
# Requirement already satisfied: pandas>=1.3.5 in /opt/conda/lib/python3.11/site-packages (from statsforecast) (2.2.0)
# Requirement already satisfied: scipy>=1.7.3 in /opt/conda/lib/python3.11/site-packages (from statsforecast) (1.12.0)
# Requirement already satisfied: statsmodels>=0.13.2 in /opt/conda/lib/python3.11/site-packages (from statsforecast) (0.14.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from statsforecast) (4.66.1)
# Collecting fugue>=0.8.1 (from statsforecast)
#   Downloading fugue-0.8.7-py3-none-any.whl.metadata (17 kB)
# Collecting utilsforecast>=0.0.24 (from statsforecast)
#   Downloading utilsforecast-0.0.26-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: threadpoolctl in /opt/conda/lib/python3.11/site-packages (from statsforecast) (3.2.0)
# Collecting triad>=0.9.3 (from fugue>=0.8.1->statsforecast)
#   Downloading triad-0.9.5-py3-none-any.whl.metadata (6.1 kB)
# Collecting adagio>=0.2.4 (from fugue>=0.8.1->statsforecast)
#   Downloading adagio-0.2.4-py3-none-any.whl (26 kB)
# Collecting qpd>=0.4.4 (from fugue>=0.8.1->statsforecast)
#   Downloading qpd-0.4.4-py3-none-any.whl.metadata (6.4 kB)
# Collecting fugue-sql-antlr>=0.1.6 (from fugue>=0.8.1->statsforecast)
#   Downloading fugue-sql-antlr-0.2.0.tar.gz (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 1.8 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting sqlglot (from fugue>=0.8.1->statsforecast)
#   Downloading sqlglot-20.11.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from fugue>=0.8.1->statsforecast) (3.1.3)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/conda/lib/python3.11/site-packages (from numba>=0.55.0->statsforecast) (0.41.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.3.5->statsforecast) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.3.5->statsforecast) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.3.5->statsforecast) (2023.4)
# Requirement already satisfied: patsy>=0.5.4 in /opt/conda/lib/python3.11/site-packages (from statsmodels>=0.13.2->statsforecast) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /opt/conda/lib/python3.11/site-packages (from statsmodels>=0.13.2->statsforecast) (23.2)
# Collecting antlr4-python3-runtime<4.12 (from fugue-sql-antlr>=0.1.6->fugue>=0.8.1->statsforecast)
#   Downloading antlr4_python3_runtime-4.11.1-py3-none-any.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: six in /opt/conda/lib/python3.11/site-packages (from patsy>=0.5.4->statsmodels>=0.13.2->statsforecast) (1.16.0)
# Requirement already satisfied: pyarrow>=6.0.1 in /opt/conda/lib/python3.11/site-packages (from triad>=0.9.3->fugue>=0.8.1->statsforecast) (14.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in /opt/conda/lib/python3.11/site-packages (from triad>=0.9.3->fugue>=0.8.1->statsforecast) (2023.12.2)
# Collecting fs (from triad>=0.9.3->fugue>=0.8.1->statsforecast)
#   Downloading fs-2.4.16-py2.py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->fugue>=0.8.1->statsforecast) (2.1.4)
# Collecting appdirs~=1.4.3 (from fs->triad>=0.9.3->fugue>=0.8.1->statsforecast)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from fs->triad>=0.9.3->fugue>=0.8.1->statsforecast) (69.0.3)
# Downloading statsforecast-1.7.2-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.9/119.9 kB 3.9 MB/s eta 0:00:00
# Downloading fugue-0.8.7-py3-none-any.whl (279 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 279.8/279.8 kB 7.8 MB/s eta 0:00:00:00:01
# Downloading utilsforecast-0.0.26-py3-none-any.whl (38 kB)
# Downloading qpd-0.4.4-py3-none-any.whl (169 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.2/169.2 kB 6.7 MB/s eta 0:00:00
# Downloading triad-0.9.5-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 3.4 MB/s eta 0:00:00
# Downloading sqlglot-20.11.0-py3-none-any.whl (356 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.5/356.5 kB 8.3 MB/s eta 0:00:00:00:01
# Building wheels for collected packages: fugue-sql-antlr
#   Building wheel for fugue-sql-antlr (setup.py) ... done
#   Created wheel for fugue-sql-antlr: filename=fugue_sql_antlr-0.2.0-py3-none-any.whl size=158196 sha256=549e706621f02c6bc1f2b6fd3d8fed06e58cab772bdd1f3f02b640e26406e086
#   Stored in directory: /home/jovyan/.cache/pip/wheels/20/28/44/56ed13bbca1ef7e28df4a6142109ef2c3e9fe13fbc3afa8f9e
# Successfully built fugue-sql-antlr
# Installing collected packages: appdirs, antlr4-python3-runtime, sqlglot, fs, utilsforecast, triad, fugue-sql-antlr, adagio, qpd, fugue, statsforecast
# Successfully installed adagio-0.2.4 antlr4-python3-runtime-4.11.1 appdirs-1.4.4 fs-2.4.16 fugue-0.8.7 fugue-sql-antlr-0.2.0 qpd-0.4.4 sqlglot-20.11.0 statsforecast-1.7.2 triad-0.9.5 utilsforecast-0.0.26

# %%
from statsforecast import StatsForecast
from statsforecast.models import AutoARIMA

# %%
from pmdarima import auto_arima

# %%
auto_arima(forecast_data["Amount"], seasonal=True, m=12).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                   45
# Model:             SARIMAX(3, 0, 0)x(0, 0, [1], 12)   Log Likelihood                -609.861
# Date:                              Sat, 03 Feb 2024   AIC                           1231.721
# Time:                                      21:41:11   BIC                           1242.561
# Sample:                                  04-01-2020   HQIC                          1235.762
#                                        - 12-01-2023
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   2.298e+05   1.28e+05      1.796      0.072   -2.09e+04    4.81e+05
# ar.L1          0.7172      0.224      3.207      0.001       0.279       1.156
# ar.L2         -0.0199      0.437     -0.046      0.964      -0.876       0.836
# ar.L3         -0.1825      0.340     -0.537      0.591      -0.848       0.483
# ma.S.L12       0.6005      0.332      1.808      0.071      -0.050       1.251
# sigma2      3.838e+10      0.011   3.35e+12      0.000    3.84e+10    3.84e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 4.56
# Prob(Q):                              0.97   Prob(JB):                         0.10
# Heteroskedasticity (H):               0.82   Skew:                             0.56
# Prob(H) (two-sided):                  0.70   Kurtosis:                         4.08
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.28e+32. Standard errors may be unstable.
# """

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
h = 12

train, test = split_dataset(forecast_data["Amount"], horizon=h)
model = SARIMAX(train, order=(3, 0, 0), seasonal_order=(0, 0, [1], 12)).fit()
train.plot()
test.plot()
model.forecast(h).plot()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.38512D+01    |proj g|=  3.97406D-01
#
# At iterate    5    f=  1.37271D+01    |proj g|=  1.81970D-02
#
# At iterate   10    f=  1.37265D+01    |proj g|=  9.94111D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     11     12      1     0     0   2.740D-06   1.373D+01
#   F =   13.726466104634117
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# /opt/conda/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# <Axes: xlabel='DateId'>
