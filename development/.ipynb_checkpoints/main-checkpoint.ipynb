# %% [markdown]
# # Imports

# %%
# !pip install statsforecast
# Out:
# Requirement already satisfied: statsforecast in /opt/conda/lib/python3.11/site-packages (1.7.3)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.11/site-packages (from statsforecast) (3.0.0)
# Requirement already satisfied: numba>=0.55.0 in /opt/conda/lib/python3.11/site-packages (from statsforecast) (0.59.0)
# Requirement already satisfied: numpy>=1.21.6 in /opt/conda/lib/python3.11/site-packages (from statsforecast) (1.26.4)
# Requirement already satisfied: pandas>=1.3.5 in /opt/conda/lib/python3.11/site-packages (from statsforecast) (2.2.1)
# Requirement already satisfied: scipy>=1.7.3 in /opt/conda/lib/python3.11/site-packages (from statsforecast) (1.12.0)
# Requirement already satisfied: statsmodels>=0.13.2 in /opt/conda/lib/python3.11/site-packages (from statsforecast) (0.14.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from statsforecast) (4.66.2)
# Requirement already satisfied: fugue>=0.8.1 in /opt/conda/lib/python3.11/site-packages (from statsforecast) (0.8.7)
# Requirement already satisfied: utilsforecast>=0.0.24 in /opt/conda/lib/python3.11/site-packages (from statsforecast) (0.1.1)
# Requirement already satisfied: threadpoolctl in /opt/conda/lib/python3.11/site-packages (from statsforecast) (3.3.0)
# Requirement already satisfied: triad>=0.9.3 in /opt/conda/lib/python3.11/site-packages (from fugue>=0.8.1->statsforecast) (0.9.5)
# Requirement already satisfied: adagio>=0.2.4 in /opt/conda/lib/python3.11/site-packages (from fugue>=0.8.1->statsforecast) (0.2.4)
# Requirement already satisfied: qpd>=0.4.4 in /opt/conda/lib/python3.11/site-packages (from fugue>=0.8.1->statsforecast) (0.4.4)
# Requirement already satisfied: fugue-sql-antlr>=0.1.6 in /opt/conda/lib/python3.11/site-packages (from fugue>=0.8.1->statsforecast) (0.2.0)
# Requirement already satisfied: sqlglot in /opt/conda/lib/python3.11/site-packages (from fugue>=0.8.1->statsforecast) (22.3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from fugue>=0.8.1->statsforecast) (3.1.3)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /opt/conda/lib/python3.11/site-packages (from numba>=0.55.0->statsforecast) (0.42.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.3.5->statsforecast) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.3.5->statsforecast) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.3.5->statsforecast) (2024.1)
# Requirement already satisfied: patsy>=0.5.4 in /opt/conda/lib/python3.11/site-packages (from statsmodels>=0.13.2->statsforecast) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /opt/conda/lib/python3.11/site-packages (from statsmodels>=0.13.2->statsforecast) (24.0)
# Requirement already satisfied: antlr4-python3-runtime<4.12 in /opt/conda/lib/python3.11/site-packages (from fugue-sql-antlr>=0.1.6->fugue>=0.8.1->statsforecast) (4.11.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.11/site-packages (from patsy>=0.5.4->statsmodels>=0.13.2->statsforecast) (1.16.0)
# Requirement already satisfied: pyarrow>=6.0.1 in /opt/conda/lib/python3.11/site-packages (from triad>=0.9.3->fugue>=0.8.1->statsforecast) (15.0.0)
# Requirement already satisfied: fsspec>=2022.5.0 in /opt/conda/lib/python3.11/site-packages (from triad>=0.9.3->fugue>=0.8.1->statsforecast) (2024.2.0)
# Requirement already satisfied: fs in /opt/conda/lib/python3.11/site-packages (from triad>=0.9.3->fugue>=0.8.1->statsforecast) (2.4.16)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->fugue>=0.8.1->statsforecast) (2.1.5)
# Requirement already satisfied: appdirs~=1.4.3 in /opt/conda/lib/python3.11/site-packages (from fs->triad>=0.9.3->fugue>=0.8.1->statsforecast) (1.4.4)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from fs->triad>=0.9.3->fugue>=0.8.1->statsforecast) (69.1.1)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from   scipy import stats

from statsforecast import StatsForecast
from statsforecast.models import AutoARIMA
# Out:
# /opt/conda/lib/python3.11/site-packages/statsforecast/core.py:26: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# /opt/conda/lib/python3.11/site-packages/statsforecast/utils.py:237: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   "ds": pd.date_range(start="1949-01-01", periods=len(AirPassengers), freq="M"),

# %%
plt.rcParams["figure.figsize"] = 12,6

# %% [markdown]
# ## Read Data

# %%
data_path   = "./data/"
sales       = pd.read_excel(data_path + "sales.xlsx", index_col="DateId", parse_dates=True)
sales.head()
# Out:
#             DistributorId  CustomerId  Channel-Id  ProductId  \
# DateId
# 2020-04-09             10       36485         274      12555
# 2020-04-09             10       36485         274      12557
# 2020-04-09             10       36485         274      12563
# 2020-04-09             10       36485         274      12565
# 2020-04-09             10       36487         274      12596
#
#             ProductBasePrice  DiscountRate  Amount     Total InvoiceTip
# DateId
# 2020-04-09              9.52             0     960   9139.20    SELLING
# 2020-04-09             13.62             0    1392  18959.04    SELLING
# 2020-04-09             23.92             0     816  19518.72    SELLING
# 2020-04-09             16.36             0    1200  19632.00    SELLING
# 2020-04-09              6.74             0      24    161.76    SELLING

# %%
categories  = pd.read_excel(data_path + "categories.xlsx")
categories.columns = ("ProductId", "Category")
categories
# Out:
#     ProductId       Category
# 0       12555   PEST CONTROL
# 1       12557   PEST CONTROL
# 2       12563   PEST CONTROL
# 3       12565   PEST CONTROL
# 4       12566   PEST CONTROL
# 5       12569   PEST CONTROL
# 6       12588  HOME CLEANERS
# 7       12596  HOME CLEANERS
# 8       12659  HOME CLEANERS
# 9       12660  HOME CLEANERS
# 10      12665  HOME CLEANERS
# 11      13401  HOME CLEANERS
# 12      13404   PEST CONTROL
# 13      13405   PEST CONTROL
# 14      13564  HOME CLEANERS
# 15      13611   PEST CONTROL
# 16      34778       AIR CARE
# 17      54610       AIR CARE
# 18      57246       AIR CARE
# 19      68499       AIR CARE
# 20      70458  HOME CLEANERS
# 21      71182       AIR CARE
# 22      75035       AIR CARE
# 23      75085       AIR CARE
# 24      81295       AIR CARE
# 25      81296       AIR CARE
# 26      83149   PEST CONTROL
# 27      83616  HOME CLEANERS
# 28      83624  HOME CLEANERS

# %%
sales
# Out:
#             DistributorId  CustomerId  Channel-Id  ProductId  \
# DateId
# 2020-04-09             10       36485         274      12555
# 2020-04-09             10       36485         274      12557
# 2020-04-09             10       36485         274      12563
# 2020-04-09             10       36485         274      12565
# 2020-04-09             10       36487         274      12596
# ...                   ...         ...         ...        ...
# 2023-04-13             91       76224         275      68499
# 2023-04-13             91       76224         275      71182
# 2023-04-13             91       76224         275      75035
# 2023-04-13             91       76224         275      75085
# 2023-04-13             91       76224         275      81296
#
#             ProductBasePrice  DiscountRate  Amount     Total InvoiceTip
# DateId
# 2020-04-09              9.52             0     960   9139.20    SELLING
# 2020-04-09             13.62             0    1392  18959.04    SELLING
# 2020-04-09             23.92             0     816  19518.72    SELLING
# 2020-04-09             16.36             0    1200  19632.00    SELLING
# 2020-04-09              6.74             0      24    161.76    SELLING
# ...                      ...           ...     ...       ...        ...
# 2023-04-13             37.18             0      36   1338.48    SELLING
# 2023-04-13             52.43             0     259  13579.37    SELLING
# 2023-04-13             52.43             0     258  13526.94    SELLING
# 2023-04-13             52.43             0     371  19451.53    SELLING
# 2023-04-13            119.63             0      15   1794.45    SELLING
#
# [123090 rows x 9 columns]

# %%
sales = pd.merge(left=sales.reset_index(), right=categories, on="ProductId", how="left").set_index("DateId")

# %% [markdown]
# ## Investigate Data

# %%
# Check nullity
sales.isna().sum()
# Out:
# DistributorId       0
# CustomerId          0
# Channel-Id          0
# ProductId           0
# ProductBasePrice    0
# DiscountRate        0
# Amount              0
# Total               0
# InvoiceTip          0
# Category            0
# dtype: int64

# %%
# Check duplicates
duplicate_check_sales         = sales.copy()
duplicate_check_sales["Date"] = duplicate_check_sales.index
print(duplicate_check_sales.duplicated().sum(), "duplicates")

del duplicate_check_sales
# Out:
# 0 duplicates

# %%
sales["InvoiceTip"].value_counts(normalize=True)
# Out:
# InvoiceTip
# SELLING           0.976066
# SELLING_RETURN    0.023934
# Name: proportion, dtype: float64

# %%
def plot_amount_with_selling_type(sales, lower_limit=None, upper_limit=None, plot_lim=None, title="Untitled"):
    size = 10
    
    selling_data = sales.query("InvoiceTip == 'SELLING'")

    if lower_limit:
        plt.axhline(lower_limit, color="black")

    if upper_limit:
        plt.axhline(upper_limit, color="black")
    
    plt.scatter(x=selling_data.index, 
                y=selling_data["Amount"].values,
                s=size, 
                label="Selling")
    
    selling_data = sales.query("InvoiceTip == 'SELLING_RETURN'")
    plt.scatter(x=selling_data.index, 
                y=selling_data["Amount"].values,
                s=size, 
                label="Return")
    
    plt.xlabel("Date")
    plt.ylabel("Amount")
    
    if plot_lim:
        plt.ylim(-plot_lim, plot_lim)
        
    plt.title(title)
    plt.legend()
    plt.show()

# %%
plot_amount_with_selling_type(sales, title="Total Sales")

# %% [markdown]
# ## Outlier Detection

# %%
mean        = sales["Amount"].mean()
std         = sales["Amount"].std()

z_limit     = 10
z_threshold = mean + z_limit * std
print(z_threshold)
# Out:
# 15668.171336451449

# %%
plot_amount_with_selling_type(sales, lower_limit=-z_threshold, upper_limit=z_threshold, 
                              title=f"Amount of Total Sales with {z_limit} z-score interval")

# %%
# Check outliers

outlier_data = sales.query("Amount > @z_threshold or Amount < -@z_threshold").copy()
inlier_data  = sales.drop(outlier_data.index)
print(f"{round(len(outlier_data) / len(sales), 4)} of data is considered as outlier at {z_limit} * std level.")
print(
f"""
Mean before filtering = {sales["Amount"].mean()}
Mean after filtering  = {inlier_data["Amount"].mean()}
""")
# Out:
# 0.0005 of data is considered as outlier at 10 * std level.
#
# Mean before filtering = 123.48310991957105
# Mean after filtering  = 98.90161228096935

# %% [markdown]
# Frequenct of products in outlier data

# %%
outlier_data["ProductId"].value_counts().head()
# Out:
# ProductId
# 12555    46
# 12569    11
# 12659     1
# 12596     1
# 12557     1
# Name: count, dtype: int64

# %% [markdown]
# ### Endog. outliers

# %%
# Z Score of Amount by ProductId
sales['AmountZScore'] = sales.groupby('ProductId')['Amount'].transform(stats.zscore)

# %%
sales["AmountZScore"].isna().sum()
# Out:
# 0

# %%
# Endogenous Outlier Detection
outlier_ratio_per_product = (
    sales[sales["AmountZScore"] > z_limit].groupby("ProductId")["AmountZScore"].count().sort_values(ascending=False) / 
    sales["ProductId"].value_counts()).rename("ratio").fillna(0)
outlier_info_sales = pd.merge(left=outlier_ratio_per_product, 
                           right=sales["ProductId"].value_counts(), 
                           right_index=True,
                           left_index= True,
                           how="outer")
outlier_info_sales.sort_values(by="count", ascending=False).head()
# Out:
#               ratio  count
# ProductId
# 12555      0.000921  17381
# 12569      0.001533  10440
# 12557      0.002024  10373
# 12565      0.000739   8118
# 12563      0.000902   7762

# %%
filtered_sales = sales[sales["AmountZScore"].abs() < z_limit].copy()
filtered_sales.describe()
# Out:
#        DistributorId     CustomerId     Channel-Id      ProductId  \
# count  122885.000000  122885.000000  122885.000000  122885.000000
# mean       34.044879   41712.162770     273.924271   20802.660089
# std        20.142145   13837.569005       1.615534   19908.600570
# min        10.000000   20465.000000     272.000000   12555.000000
# 25%        19.000000   36435.000000     272.000000   12563.000000
# 50%        33.000000   37825.000000     274.000000   12588.000000
# 75%        38.000000   41965.000000     274.000000   13405.000000
# max        91.000000   80906.000000     280.000000   83624.000000
#
#        ProductBasePrice   DiscountRate         Amount         Total  \
# count     122885.000000  122885.000000  122885.000000  1.228850e+05
# mean          31.408382       3.024128     101.483167  2.939140e+03
# std           25.719343       5.184620     590.368394  1.889902e+04
# min            3.850000       0.000000  -22056.000000 -3.933120e+05
# 25%           13.850000       0.000000       9.000000  1.881600e+02
# 50%           23.740000       0.000000      15.000000  4.556000e+02
# 75%           41.010000       4.000000      48.000000  1.394400e+03
# max          623.820000     107.000000   34560.000000  2.277531e+06
#
#         AmountZScore
# count  122885.000000
# mean       -0.024882
# std         0.599170
# min        -9.971100
# 25%        -0.209489
# 50%        -0.140100
# 75%        -0.078065
# max         9.910688

# %% [markdown]
# ## Feature Engineering and Product Filtering

# %%
first_date_in_sales, last_date_in_sales = filtered_sales.index.min(), filtered_sales.index.max()
filtered_sales["DaystoLastDateInSales"]  = (last_date_in_sales - filtered_sales.index).days

# %%
print(f"First sale on {first_date_in_sales.date()} \nLast sale on  {last_date_in_sales.date()}")
print(f"Windows is {round((last_date_in_sales - first_date_in_sales).days / 364, 2)} years")
# Out:
# First sale on 2020-04-09
# Last sale on  2023-09-30
# Windows is 3.49 years

# %% [markdown]
# ### Product Details and Eligible Products

# %%
outlier_info_sales.columns = ["Outlier Ratio", "Outlier Count"]
outlier_info_sales.head()
# Out:
#            Outlier Ratio  Outlier Count
# ProductId
# 12555           0.000921          17381
# 12557           0.002024          10373
# 12563           0.000902           7762
# 12565           0.000739           8118
# 12566           0.001913           5749

# %%
inactive_threshold = 364
long_enough        = 364
min_sales          = 100
date_quantile      = .95

filtered_sales["Date"] = pd.to_datetime(filtered_sales.index)

product_details                                 = filtered_sales.groupby("ProductId")["Date"].agg(["min", "max"])
product_details.columns                         = ["FirstSaleDate", "LastSaleDate"]

# Date Related
product_details["DaysSoldFor"]                  = (product_details["LastSaleDate"] - product_details["FirstSaleDate"]).dt.days
product_details["DaysSinceLastSaleDate"]        = (last_date_in_sales - product_details["LastSaleDate"]).dt.days

# Validity of the product
product_details["IsActive"]                     = product_details["DaysSinceLastSaleDate"].apply(lambda day: day < inactive_threshold)
product_details["IsSoldEnough"]                 = product_details["DaysSoldFor"].apply(lambda days: days > long_enough)

# Sales volume
product_details["TotalSaleAmount"]              = filtered_sales.groupby("ProductId")["Amount"].sum()
product_details["MeanSaleAmountPerMonth"]       = product_details["TotalSaleAmount"] / (product_details["DaysSoldFor"] / 30)

# Maybe we can add quantile test?

query_              = """IsActive               == True and \
                         IsSoldEnough           == True and \
                         MeanSaleAmountPerMonth >= @min_sales
                      """
eligible_products                               = product_details.query(query_).copy()

print(f"{eligible_products.count().min()} of {len(sales.ProductId.unique())} products are eligible for forecasting.")

del filtered_sales["Date"]
# Out:
# 26 of 29 products are eligible for forecasting.

# %%
product_details
# Out:
#           FirstSaleDate LastSaleDate  DaysSoldFor  DaysSinceLastSaleDate  \
# ProductId
# 12555        2020-04-09   2023-09-30         1269                      0
# 12557        2020-04-09   2023-09-30         1269                      0
# 12563        2020-04-09   2023-09-29         1268                      1
# 12565        2020-04-09   2023-09-30         1269                      0
# 12566        2020-04-14   2023-09-29         1263                      1
# 12569        2020-04-09   2023-09-30         1269                      0
# 12588        2020-04-09   2023-09-26         1265                      4
# 12596        2020-04-09   2023-09-30         1269                      0
# 12659        2020-04-09   2023-09-30         1269                      0
# 12660        2020-04-09   2023-09-29         1268                      1
# 12665        2020-04-09   2023-09-30         1269                      0
# 13401        2020-05-02   2023-09-30         1246                      0
# 13404        2020-05-22   2023-09-27         1223                      3
# 13405        2020-05-05   2023-09-29         1242                      1
# 13564        2020-06-11   2023-09-29         1205                      1
# 13611        2020-06-22   2023-09-29         1194                      1
# 34778        2021-02-18   2023-09-30          954                      0
# 54610        2021-06-14   2023-09-30          838                      0
# 57246        2021-06-14   2023-09-30          838                      0
# 68499        2021-10-12   2023-09-30          718                      0
# 70458        2021-12-06   2023-09-30          663                      0
# 71182        2022-02-22   2023-09-29          584                      1
# 75035        2022-03-04   2023-09-30          575                      0
# 75085        2022-03-18   2023-09-30          561                      0
# 81295        2022-05-23   2023-09-30          495                      0
# 81296        2022-05-19   2023-09-30          499                      0
# 83149        2023-03-15   2023-09-30          199                      0
# 83616        2023-08-14   2023-09-29           46                      1
# 83624        2023-08-15   2023-09-29           45                      1
#
#            IsActive  IsSoldEnough  TotalSaleAmount  MeanSaleAmountPerMonth
# ProductId
# 12555          True          True          4623122           109293.664303
# 12557          True          True           865486            20460.661939
# 12563          True          True           468414            11082.350158
# 12565          True          True           443283            10479.503546
# 12566          True          True           219960             5224.703088
# 12569          True          True          1831444            43296.548463
# 12588          True          True           157405             3732.924901
# 12596          True          True           625456            14786.193853
# 12659          True          True           521095            12319.030733
# 12660          True          True           141425             3346.017350
# 12665          True          True           148510             3510.874704
# 13401          True          True           164543             3961.709470
# 13404          True          True           313003             7677.914963
# 13405          True          True           166504             4021.835749
# 13564          True          True           108215             2694.149378
# 13611          True          True           354911             8917.361809
# 34778          True          True           307645             9674.371069
# 54610          True          True            36868             1319.856802
# 57246          True          True            32853             1176.121718
# 68499          True          True           390722            16325.431755
# 70458          True          True           113208             5122.533937
# 71182          True          True            33706             1731.472603
# 75035          True          True            38605             2014.173913
# 75085          True          True            37082             1982.994652
# 81295          True          True            17752             1075.878788
# 81296          True          True            18935             1138.376754
# 83149          True         False           276467            41678.442211
# 83616          True         False             7846             5116.956522
# 83624          True         False             6294             4196.000000

# %% [markdown]
# 83149, 83616, 83624 are not suitable for forecasting since they haven't been sold for more than one year.

# %%
monthly_resample = filtered_sales.resample("MS")
total_agg = monthly_resample[["Amount"]].sum().copy()
total_agg.plot()
# Out:
# <Axes: xlabel='DateId'>

# %% [markdown]
# # Forecasting

# %%
pest_control_agg = filtered_sales.query("Category== 'PEST CONTROL' ").resample("MS").Amount.sum()

# %%
def split_dataset(data, horizon, timeshift=0):
    train = data.iloc[:-(horizon + timeshift)]
    test  = data.iloc[-(horizon + timeshift):]
    return train,test

# %%
train, test = split_dataset(pest_control_agg, horizon=3, timeshift=0)

# %%
plt.plot(train)
plt.plot(test)
plt.show()
